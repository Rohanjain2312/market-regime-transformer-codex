# %% [markdown]
# # Exploratory Analysis
#
# Starter notebook for inspecting downloaded market and macro data, engineered features, and regime labels.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from src.data_loader import download_and_prepare
from src.features import build_feature_matrix
from src.config import get_config

cfg = get_config()

merged = download_and_prepare(cfg)
features = build_feature_matrix(merged, cfg)

display(features.head())
features[['log_return', 'volatility']].plot(subplots=True, figsize=(12, 6))
plt.tight_layout()
plt.show()
